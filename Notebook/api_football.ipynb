# %% [markdown]
# ++++ pulling into from the api-football.com
#
# documentaiton: https://www.api-football.com/documentation-v3
# website: https://www.api-football.com/

# %%
import requests
from dotenv import load_dotenv
import os

# %%
### setting up api key in .env file 

load_dotenv()
api_key = os.getenv("api_football_key")

# %%
url = "https://v3.football.api-sports.io/"

headers = {"x-apisports-key": api_key}

#params = {"name": "us",
          "category": "sports"
          }

response = requests.get(url, headers=headers)
response
# Out:
#   Cell In[10], line 6
#     "category": "sports"
#     ^
# IndentationError: unexpected indent

# %%
response.json()
# Out:
# {'api': {'code': 200,
#   'results': 0,
#   'error': 'NOT AUTORIZED, API KEY MISSING OR USER BLOCKED. PLEASE CONTACT OUR SUPPORT.'}}
